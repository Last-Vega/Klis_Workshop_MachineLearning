# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
csvPath = './PokemonDataCSV/'
csvName = 'pokedex_(Update_05.20).csv'
pokedex = pd.read_csv(csvPath+csvName)
pokedex = pokedex.drop(['Unnamed: 0'], axis=1)
pokedex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 50 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pokedex_number    1028 non-null   int64
#  1   name              1028 non-null   object
#  2   german_name       938 non-null    object
#  3   japanese_name     938 non-null    object
#  4   generation        1028 non-null   int64
#  5   status            1028 non-null   object
#  6   species           1028 non-null   object
#  7   type_number       1028 non-null   int64
#  8   type_1            1028 non-null   object
#  9   type_2            542 non-null    object
#  10  height_m          1028 non-null   float64
#  11  weight_kg         1027 non-null   float64
#  12  abilities_number  1028 non-null   int64
#  13  ability_1         1025 non-null   object
#  14  ability_2         513 non-null    object
#  15  ability_hidden    810 non-null    object
#  16  total_points      1028 non-null   float64
#  17  hp                1028 non-null   float64
#  18  attack            1028 non-null   float64
#  19  defense           1028 non-null   float64
#  20  sp_attack         1028 non-null   float64
#  21  sp_defense        1028 non-null   float64
#  22  speed             1028 non-null   float64
#  23  catch_rate        924 non-null    float64
#  24  base_friendship   924 non-null    float64
#  25  base_experience   924 non-null    float64
#  26  growth_rate       1027 non-null   object
#  27  egg_type_number   1028 non-null   int64
#  28  egg_type_1        1025 non-null   object
#  29  egg_type_2        282 non-null    object
#  30  percentage_male   792 non-null    float64
#  31  egg_cycles        1027 non-null   float64
#  32  against_normal    1028 non-null   float64
#  33  against_fire      1028 non-null   float64
#  34  against_water     1028 non-null   float64
#  35  against_electric  1028 non-null   float64
#  36  against_grass     1028 non-null   float64
#  37  against_ice       1028 non-null   float64
#  38  against_fight     1028 non-null   float64
#  39  against_poison    1028 non-null   float64
#  40  against_ground    1028 non-null   float64
#  41  against_flying    1028 non-null   float64
#  42  against_psychic   1028 non-null   float64
#  43  against_bug       1028 non-null   float64
#  44  against_rock      1028 non-null   float64
#  45  against_ghost     1028 non-null   float64
#  46  against_dragon    1028 non-null   float64
#  47  against_dark      1028 non-null   float64
#  48  against_steel     1028 non-null   float64
#  49  against_fairy     1028 non-null   float64
# dtypes: float64(32), int64(5), object(13)
# memory usage: 401.7+ KB

# %%
#使用するデータのみで表を作る
pokedex = pokedex[ ['pokedex_number', 'name', 'japanese_name', 'type_number', 'type_1', 'type_2',
                   'egg_type_number', 'egg_type_1', 'egg_type_2'] ]
pokedex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pokedex_number   1028 non-null   int64
#  1   name             1028 non-null   object
#  2   japanese_name    938 non-null    object
#  3   type_number      1028 non-null   int64
#  4   type_1           1028 non-null   object
#  5   type_2           542 non-null    object
#  6   egg_type_number  1028 non-null   int64
#  7   egg_type_1       1025 non-null   object
#  8   egg_type_2       282 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 72.4+ KB

# %%
# egg_type_1が欠損値の行を削除（主にメガ進化ポケモン）
pokedex = pokedex.dropna(subset=['egg_type_1'])
# pokedex_numberが重複している行を削除（主にメガ進化ポケモン）
pokedex = pokedex.drop_duplicates(subset=['pokedex_number'])

# %%
import os
from os import listdir
# 画像ファイルの読み込み
imageDir = "./ValidationData/"
# .DS_Storeの削除
fltr_list = [filename for filename in listdir(imageDir) if not filename.startswith('.')]
fltr_list = [filename for filename in listdir(imageDir) if not '-' in filename]

# %%
fileNameLists = []
fileNumberLists = []
for filename in fltr_list:
    fileNameLists.append(filename)
    fileNumber = filename.split('.')[0]
#     if fileNumber == '':
#         continue
    fileNumber = int(fileNumber)
    fileNumberLists.append(fileNumber)

pokedex2 = pd.DataFrame( [fileNumberLists, fileNameLists], index=['pokedex_number', 'image_name'] )
pokedex2 = pokedex2.T

# %%
pokedex2
# Out:
#     pokedex_number image_name
# 0              348    348.png
# 1              412    412.png
# 2              374    374.png
# 3              360    360.png
# 4              406    406.png
# ..             ...        ...
# 716            379    379.png
# 717            423    423.png
# 718            345    345.png
# 719            351    351.png
# 720            437    437.png
#
# [721 rows x 2 columns]

# %%
pokedex3 = pd.merge(pokedex, pokedex2, on='pokedex_number', how='inner' )

# %%
pokedex3.head(30)
# Out:
#    pokedex_number        name        japanese_name  type_number    type_1  \
# 0               1   Bulbasaur  フシギダネ (Fushigidane)            2     Grass
# 1               2     Ivysaur   フシギソウ (Fushigisou)            2     Grass
# 2               3    Venusaur  フシギバナ (Fushigibana)            2     Grass
# 3               4  Charmander      ヒトカゲ (Hitokage)            1      Fire
# 4               5  Charmeleon       リザード (Lizardo)            1      Fire
# 5               6   Charizard     リザードン (Lizardon)            2      Fire
# 6               7    Squirtle      ゼニガメ (Zenigame)            1     Water
# 7               8   Wartortle        カメール (Kameil)            1     Water
# 8               9   Blastoise        カメックス (Kamex)            1     Water
# 9              10    Caterpie     キャタピー (Caterpie)            1       Bug
# 10             11     Metapod      トランセル (Transel)            1       Bug
# 11             12  Butterfree   バタフリー (Butterfree)            2       Bug
# 12             13      Weedle        ビードル (Beedle)            2       Bug
# 13             14      Kakuna        コクーン (Cocoon)            2       Bug
# 14             15    Beedrill         スピアー (Spear)            2       Bug
# 15             16      Pidgey          ポッポ (Poppo)            2    Normal
# 16             17   Pidgeotto        ピジョン (Pigeon)            2    Normal
# 17             18     Pidgeot       ピジョット (Pigeot)            2    Normal
# 18             19     Rattata       コラッタ (Koratta)            1    Normal
# 19             20    Raticate          ラッタ (Ratta)            1    Normal
# 20             21     Spearow    オニスズメ (Onisuzume)            2    Normal
# 21             22      Fearow     オニドリル (Onidrill)            2    Normal
# 22             23       Ekans           アーボ (Arbo)            1    Poison
# 23             24       Arbok        アーボック (Arbok)            1    Poison
# 24             25     Pikachu      ピカチュウ (Pikachu)            1  Electric
# 25             26      Raichu       ライチュウ (Raichu)            1  Electric
# 26             27   Sandshrew           サンド (Sand)            1    Ground
# 27             28   Sandslash      サンドパン (Sandpan)            1    Ground
# 28             29    Nidoran♀     ニドラン♀ (Nidoran♀)            1    Poison
# 29             30    Nidorina     ニドリーナ (Nidorina)            1    Poison
#
#     type_2  egg_type_number    egg_type_1 egg_type_2 image_name
# 0   Poison                2         Grass    Monster      1.png
# 1   Poison                2         Grass    Monster      2.png
# 2   Poison                2         Grass    Monster      3.png
# 3      NaN                2        Dragon    Monster      4.png
# 4      NaN                2        Dragon    Monster      5.png
# 5   Flying                2        Dragon    Monster      6.png
# 6      NaN                2       Monster    Water 1      7.png
# 7      NaN                2       Monster    Water 1      8.png
# 8      NaN                2       Monster    Water 1      9.png
# 9      NaN                1           Bug        NaN     10.png
# 10     NaN                1           Bug        NaN     11.png
# 11  Flying                1           Bug        NaN     12.png
# 12  Poison                1           Bug        NaN     13.png
# 13  Poison                1           Bug        NaN     14.png
# 14  Poison                1           Bug        NaN     15.png
# 15  Flying                1        Flying        NaN     16.png
# 16  Flying                1        Flying        NaN     17.png
# 17  Flying                1        Flying        NaN     18.png
# 18     NaN                1         Field        NaN     19.png
# 19     NaN                1         Field        NaN     20.png
# 20  Flying                1        Flying        NaN     21.png
# 21  Flying                1        Flying        NaN     22.png
# 22     NaN                2        Dragon      Field     23.png
# 23     NaN                2        Dragon      Field     24.png
# 24     NaN                2         Fairy      Field     25.png
# 25     NaN                2         Fairy      Field     26.png
# 26     NaN                1         Field        NaN     27.png
# 27     NaN                1         Field        NaN     28.png
# 28     NaN                2         Field    Monster     29.png
# 29     NaN                1  Undiscovered        NaN     30.png

# %%
for index, value in pokedex3['egg_type_1'].value_counts().iteritems():
    print(index, ': ', value)
# Out:
# Field :  186
# Undiscovered :  73
# Bug :  68
# Amorphous :  49
# Dragon :  47
# Fairy :  46
# Mineral :  46
# Flying :  42
# Grass :  38
# Human-Like :  36
# Monster :  31
# Water 1 :  31
# Water 3 :  14
# Water 2 :  13
# Ditto :  1

# %%
def createLabel(pokedex3):
    labels = []
    egg_type_list = ['Field', 'Undiscovered', 'Bug', 'Amorphous', 'Dragon', 'Fairy', 'Mineral', 
                    'Flying', 'Grass', 'Human-Like', 'Monster', 'Water', 'Ditto']
    
    number = 0
    for eggType1 in pokedex3['egg_type_1']:
        count = 0
        for elm in egg_type_list:
            if elm in eggType1:
                labels.append(count)
            
            else:
                count += 1
        number += 1
  
    pokedex3['label'] = labels
    return pokedex3

# %%
createLabel(pokedex3)
# Out:
#     pokedex_number                  name        japanese_name  type_number  \
# 0                1             Bulbasaur  フシギダネ (Fushigidane)            2
# 1                2               Ivysaur   フシギソウ (Fushigisou)            2
# 2                3              Venusaur  フシギバナ (Fushigibana)            2
# 3                4            Charmander      ヒトカゲ (Hitokage)            1
# 4                5            Charmeleon       リザード (Lizardo)            1
# ..             ...                   ...                  ...          ...
# 716            717               Yveltal      イベルタル (Yveltal)            2
# 717            718     Zygarde 50% Forme       ジガルデ (Zygarde)            2
# 718            719               Diancie     ディアンシー (Diancie)            2
# 719            720  Hoopa Hoopa Confined          フーパ (Hoopa)            2
# 720            721             Volcanion   ボルケニオン (Volcanion)            2
#
#       type_1  type_2  egg_type_number    egg_type_1 egg_type_2 image_name  \
# 0      Grass  Poison                2         Grass    Monster      1.png
# 1      Grass  Poison                2         Grass    Monster      2.png
# 2      Grass  Poison                2         Grass    Monster      3.png
# 3       Fire     NaN                2        Dragon    Monster      4.png
# 4       Fire     NaN                2        Dragon    Monster      5.png
# ..       ...     ...              ...           ...        ...        ...
# 716     Dark  Flying                1  Undiscovered        NaN    717.png
# 717   Dragon  Ground                1  Undiscovered        NaN    718.png
# 718     Rock   Fairy                1  Undiscovered        NaN    719.png
# 719  Psychic   Ghost                1  Undiscovered        NaN    720.png
# 720     Fire   Water                1  Undiscovered        NaN    721.png
#
#      label
# 0        8
# 1        8
# 2        8
# 3        4
# 4        4
# ..     ...
# 716      1
# 717      1
# 718      1
# 719      1
# 720      1
#
# [721 rows x 11 columns]

# %%
import shutil
egg_type_list = ['Field', 'Undiscovered', 'Bug', 'Amorphous', 'Dragon', 'Fairy', 'Mineral', 
                    'Flying', 'Grass', 'Human-Like', 'Monster', 'Water', 'Ditto']
path = './AllDataSet/validation/'
i = 0
while i < len(egg_type_list):
    os.mkdir(path + str(i))
    i += 1

# %%
for imageName, label in zip(pokedex3['image_name'], pokedex3['label']):
    i = 0
    while i < len(egg_type_list):
        if label == i:
            shutil.move(path+imageName, path+str(i))
        i += 1
